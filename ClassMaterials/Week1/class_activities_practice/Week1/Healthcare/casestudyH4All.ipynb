# %% [markdown]
# # Intro to Pandas

# %% [markdown]
# ### Numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %%
cd ..
# Out:
# /Users/polferrandis/Documents/Github/class_activities/Week1

# %%
# !ls
# Out:
# Healthcare

# %%
cd Week1
# Out:
# [Errno 2] No such file or directory: 'Week1'
# /Users/polferrandis/Documents/Github/class_activities/Week1

# %%
cd healthcare
# Out:
# /Users/polferrandis/Documents/Github/class_activities/Week1/Healthcare

# %%
# !ls
# Out:
# casestudyH4All.ipynb
# data for class.zip
# dataforclass
# file4.xlsx
# healthcare for all column definitions.docx

# %%
file1=pd.read_csv('dataforclass/file1.csv')

# %%
file1.head() #shows first rows
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file1.shape #Rows and columns
# Out:
# (1007, 17)

# %%
file1.info() #summarises content
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1007 non-null   int64
#  1   STATE     1007 non-null   object
#  2   GENDER    967 non-null    object
#  3   HV1       1005 non-null   object
#  4   IC1       1007 non-null   int64
#  5   IC4       1006 non-null   float64
#  6   HVP1      1007 non-null   int64
#  7   IC5       1007 non-null   object
#  8   POBC1     1007 non-null   int64
#  9   POBC2     1007 non-null   int64
#  10  IC2       1006 non-null   float64
#  11  IC3       1007 non-null   int64
#  12  AVGGIFT   1007 non-null   float64
#  13  TCODE     1007 non-null   int64
#  14  DOB       1007 non-null   int64
#  15  DOMAIN    1007 non-null   object
#  16  TARGET_D  1007 non-null   float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 133.9+ KB

# %%
file1.describe() #statistical summary of data
# Out:
#             CONTROLN          IC1          IC4         HVP1        POBC1  \
# count    1007.000000  1007.000000  1006.000000  1007.000000  1007.000000
# mean    98913.029791   352.015889   445.059642    16.261172     6.847071
# std     58306.879885   173.937638   178.115476    29.464477     9.333689
# min        71.000000     0.000000     0.000000     0.000000     0.000000
# 25%     44930.500000   238.500000   325.000000     0.000000     1.000000
# 50%    101113.000000   319.000000   406.000000     1.000000     4.000000
# 75%    151559.000000   421.500000   527.000000    14.000000     9.000000
# max    191779.000000  1500.000000  1263.000000    99.000000    73.000000
#
#              POBC2          IC2          IC3      AVGGIFT        TCODE  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1007.000000
# mean     55.630586   401.658052   400.022840    11.863404    37.747766
# std      21.593999   182.024618   168.901139     7.829965   213.010617
# ...

# %%
# !ls
# Out:
# casestudyH4All.ipynb
# data for class.zip
# dataforclass
# file4.xlsx
# healthcare for all column definitions.docx

# %%
file2=pd.read_csv('dataforclass/file2.txt' ,sep='\t') #reading txt file with pandas #https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
file2.head()
# Out:
#    CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
file2.shape
# Out:
# (1015, 17)

# %%
file3=pd.read_excel('dataforclass/file3.xlsx' ,engine='openpyxl') #engine make pandas open xls files

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
file4=pd.read_excel('dataforclass/file4.xlsx' ,engine='openpyxl')

# %%
file4.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    186307    CA      M  AAA1229  345  438     3  15915      2     58  388
# 1     34174    WV      F      529  198  291     0  10816      0     80  218
# 2    101388    MO      M      526  340  342     0   9687      0     89  348
# 3    159472    CA      F      621  231  279     0   6184     43     41  237
# 4    179143    WA   male     1688  496  564    35  22963      2     63  520
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  417  16.142857      1  2511     C2      20.0
# 1  257   6.083333      2  3001     T2      12.0
# 2  321   5.800000      1  5501     R2      10.0
# 3  272  11.666667      1  1512     R3      15.0
# 4  521  23.900000      1  3709     T1      25.0

# %%
columns=file1.columns #set column

# %%
columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
#create data frame, defining columns
data=pd.DataFrame(columns=columns)

# %%
data
# Out:
# Empty DataFrame
# Columns: [CONTROLN, STATE, GENDER, HV1, IC1, IC4, HVP1, IC5, POBC1, POBC2, IC2, IC3, AVGGIFT, TCODE, DOB, DOMAIN, TARGET_D]
# Index: []

# %%
data=pd.concat([data,file1],axis=0) #add data from file 1 in data frame created

# %%
data
# Out:
#      CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2  \
# 0       44060    FL      M   AAA896  392  520.0    7  21975     6    16
# 1       96093    IL      M   537.00  365  473.0    0  19387     1    89
# 2       43333    FL      F   725.00  301  436.0    3  18837    11    17
# 3       21885    NC      M  AAA1095  401  413.0    7  14014     1    74
# 4      190108    FL      F   995.00  252  348.0    0  17991     5     6
# ...       ...   ...    ...      ...  ...    ...  ...    ...   ...   ...
# 1002   114721    OK    NaN     1040  472  656.0    0  26962     2    56
# 1003   149152    CA      M     4507  842  962.0   95  54642    17    50
# 1004      959    IA      F      586  349  465.0    1  15304     1    77
# 1005   179563    WA   male      842  420  494.0    2  12894    41    24
# 1006    41243    FL      F      556  246  330.0    0  10272     2    56
#
#          IC2  IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data=pd.concat([data,file2,file3,file4],axis=0) #add data from file , 2 and 3 in data frame created

# %%
data
# Out:
#      CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2  \
# 0       44060    FL      M   AAA896  392  520.0    7  21975     6    16
# 1       96093    IL      M   537.00  365  473.0    0  19387     1    89
# 2       43333    FL      F   725.00  301  436.0    3  18837    11    17
# 3       21885    NC      M  AAA1095  401  413.0    7  14014     1    74
# 4      190108    FL      F   995.00  252  348.0    0  17991     5     6
# ...       ...   ...    ...      ...  ...    ...  ...    ...   ...   ...
# 1001    41537    FL      F      742  396  470.0    0  15356     7    37
# 1002     4881    FL      M      599  100  423.0    4  11670    10    27
# 1003    66358    ND      M      593  258  299.0    0  10186     1    70
# 1004     2231    WI   male      564  217  397.0    0  12315     0    96
# 1005    68534    MI      M      651  431  505.0    0  14845     7    77
#
#         IC2  IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
data.head()
# Out:
#   CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2    IC2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M   537.00  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F   725.00  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F   995.00  252  348.0    0  17991     5     6  280.0
#
#    IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
cols=[]
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())

#this is the function : data.columns.lower()

# %%
data.columns=cols

# %%
data.head()
# Out:
#   controln state gender      hv1  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M   537.00  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F   725.00  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F   995.00  252  348.0    0  17991     5     6  280.0
#
#    ic3    avggift tcode   dob domain  target_d
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
datanew=data.drop(['controln','hv1'],axis=1)

# %%
datanew.head()
# Out:
#   state gender  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  ic3    avggift  \
# 0    FL      M  392  520.0    7  21975     6    16  430.0  466  28.000000
# 1    IL      M  365  473.0    0  19387     1    89  415.0  410   5.666667
# 2    FL      F  301  436.0    3  18837    11    17  340.0  361   4.111111
# 3    NC      M  401  413.0    7  14014     1    74  407.0  399  27.277778
# 4    FL      F  252  348.0    0  17991     5     6  280.0  316   6.000000
#
#   tcode   dob domain  target_d
# 0     1  1901     C2     100.0
# 1     0     0     T2       7.0
# 2     0  2501     C2       5.0
# 3     0  2208     T2      38.0
# 4    28     0     C2       5.0

# %%
datanew.tail()
# Out:
#      state gender  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  ic3    avggift  \
# 1001    FL      F  396  470.0    0  15356     7    37  424.0  450  14.285714
# 1002    FL      M  100  423.0    4  11670    10    27  406.0  200   9.230769
# 1003    ND      M  258  299.0    0  10186     1    70  298.0  274   5.266667
# 1004    WI   male  217  397.0    0  12315     0    96  386.0  295  11.400000
# 1005    MI      M  431  505.0    0  14845     7    77  451.0  455   7.428571
#
#      tcode   dob domain  target_d
# 1001     2  6101     S2      50.0
# 1002    28  7401     C1      10.0
# 1003     1  3301     S2       5.0
# 1004     1  7301     T2      14.0
# 1005     1  1709     S2       9.0

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4028 entries, 0 to 1005
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     4028 non-null   object
#  1   gender    3892 non-null   object
#  2   ic1       4028 non-null   object
#  3   ic4       4027 non-null   float64
#  4   hvp1      4028 non-null   object
#  5   ic5       4028 non-null   object
#  6   pobc1     4028 non-null   object
#  7   pobc2     4028 non-null   object
#  8   ic2       4027 non-null   float64
#  9   ic3       4028 non-null   object
#  10  avggift   4028 non-null   float64
#  11  tcode     4028 non-null   object
#  12  dob       4028 non-null   object
#  13  domain    4028 non-null   object
#  14  target_d  4028 non-null   float64
# dtypes: float64(4), object(11)
# memory usage: 503.5+ KB

# %% [markdown]
# ## reset index!

# %%
datanew.reset_index(drop=True, inplace=True)

# %%
datanew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4028 entries, 0 to 4027
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     4028 non-null   object
#  1   gender    3892 non-null   object
#  2   ic1       4028 non-null   object
#  3   ic4       4027 non-null   float64
#  4   hvp1      4028 non-null   object
#  5   ic5       4028 non-null   object
#  6   pobc1     4028 non-null   object
#  7   pobc2     4028 non-null   object
#  8   ic2       4027 non-null   float64
#  9   ic3       4028 non-null   object
#  10  avggift   4028 non-null   float64
#  11  tcode     4028 non-null   object
#  12  dob       4028 non-null   object
#  13  domain    4028 non-null   object
#  14  target_d  4028 non-null   float64
# dtypes: float64(4), object(11)
# memory usage: 472.2+ KB

# %%
filtered=datanew[(datanew["state"]=='FL')&(datanew["gender"]=='M')]

# %%
filtered.head()
# Out:
#     state gender  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  ic3    avggift  \
# 0      FL      M  392  520.0    7  21975     6    16  430.0  466  28.000000
# 34     FL      M  232  269.0    0  10511    11    20  270.0  257  12.611111
# 101    FL      M  233  301.0    0   9747    63    21  239.0  290  20.000000
# 110    FL      M  248  326.0    0  15008    15     7  274.0  288  10.153846
# 137    FL      M  166  332.0   52  16019    26     3  270.0  233   2.916667
#
#     tcode   dob domain  target_d
# 0       1  1901     C2     100.0
# 34   1002  2601     S3      20.0
# 101     1     0     C3      20.0
# 110     0  1704     U1      10.0
# 137     1  2901     C1       3.0

# %%
filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 4024
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     154 non-null    object
#  1   gender    154 non-null    object
#  2   ic1       154 non-null    object
#  3   ic4       154 non-null    float64
#  4   hvp1      154 non-null    object
#  5   ic5       154 non-null    object
#  6   pobc1     154 non-null    object
#  7   pobc2     154 non-null    object
#  8   ic2       154 non-null    float64
#  9   ic3       154 non-null    object
#  10  avggift   154 non-null    float64
#  11  tcode     154 non-null    object
#  12  dob       154 non-null    object
#  13  domain    154 non-null    object
#  14  target_d  154 non-null    float64
# dtypes: float64(4), object(11)
# memory usage: 19.2+ KB

# %% [markdown]
# ## avggift< 10usd, california, females

# %%
filtered2=datanew[(datanew["state"]=='CA')&(datanew["gender"]=='F')&(datanew["avggift"]>=10)]

# %%
filtered2.shape
# Out:
# (259, 15)

# %% [markdown]
# ## same using .query()

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
filtered3=datanew.query('gender=="F"&state=="CA"&avggift>10')

# %%
filtered3.head(30)
# Out:
#      state gender  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  ic3    avggift  \
# 36      CA      F  164  190.0    0   5273    23    57  168.0  181  16.500000
# 47      CA      F  240  257.0   25   7559    57    34  238.0  262  13.500000
# 168     CA      F  504  672.0   80  22033     8    33  601.0  562  10.714286
# 197     CA      F  735  805.0   98  34382     9    55  701.0  838  15.857143
# 216     CA      F  411  503.0   27  18236    21    41  480.0  439  39.444444
# 247     CA      F  515  582.0   34  23660    15    29  511.0  575  19.000000
# 303     CA      F  267  338.0   87  11115    36    43  292.0  325  13.200000
# 305     CA      F  266  337.0   33  10720    48    32  271.0  334  20.000000
# 307     CA      F  290  381.0    6  13490     9    50  324.0  349  15.850000
# 706     CA      F  472  563.0   39  17217    31    52  531.0  530  20.000000
# 723     CA      F  451  569.0   70  17470    15    50  526.0  481  13.142857
# ...

# %%
filtered[10:30]
# Out:
#     state gender  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  ic3    avggift  \
# 203    FL      M  357  497.0    2  21444    14    15  411.0  422   9.576923
# 208    FL      M  230  295.0    0   9547     0    68  271.0  261  10.700000
# 220    FL      M  636  772.0   24  35544     0    44  693.0  680  25.000000
# 242    FL      M  479  616.0    7  20795    15    35  508.0  567   4.105769
# 255    FL      M  388  577.0   25  18405     3    37  479.0  513  18.000000
# 279    FL      M  348  459.0    3  15958     1    47  388.0  421   7.090909
# 282    FL      M  254  391.0    6  15970     4    30  287.0  325   7.285714
# 306    FL      M  259  309.0    0  11072    17    16  282.0  299  17.142857
# 315    FL      M  271  324.0    3  10488     2    52  268.0  312  16.400000
# 321    FL      M  200  324.0    0  12518     8    12  280.0  244  12.909091
# 343    FL      M  452  640.0   44  29990     6     9  542.0  553   3.818182
# ...

# %%
filtered3[['state','gender','avggift']]
# Out:
#      state gender    avggift
# 36      CA      F  16.500000
# 47      CA      F  13.500000
# 168     CA      F  10.714286
# 197     CA      F  15.857143
# 216     CA      F  39.444444
# ...    ...    ...        ...
# 3979    CA      F  20.000000
# 3981    CA      F  11.363636
# 4004    CA      F  25.843750
# 4010    CA      F  25.000000
# 4020    CA      F  12.117647
#
# [252 rows x 3 columns]

# %% [markdown]
# ## data cleaning - dtypes

# %%
data.shape
# Out:
# (4028, 17)

# %%
data.dtypes #will change data types from object to numeric and will keep the ones that are already floats
# Out:
# controln     object
# state        object
# gender       object
# hv1          object
# ic1          object
# ic4         float64
# hvp1         object
# ic5          object
# pobc1        object
# pobc2        object
# ic2         float64
# ic3          object
# avggift     float64
# tcode        object
# dob          object
# domain       object
# target_d    float64
# dtype: object

# %%
data['hv1'].astype('float',errors='ignore')
# Out:
# 0        AAA896
# 1        537.00
# 2        725.00
# 3       AAA1095
# 4        995.00
#          ...
# 1001        742
# 1002        599
# 1003        593
# 1004        564
# 1005        651
# Name: hv1, Length: 4028, dtype: object

# %%
data['hv1']=pd.to_numeric(data['hv1'],errors='coerce') #replace column witha nother column

# %%
data['ic1']=pd.to_numeric(data['ic1'],errors='coerce')

# %%
data['ic5']=pd.to_numeric(data['ic5'],errors='coerce')

# %%
data['ic3']=pd.to_numeric(data['ic3'],errors='coerce')

# %%
data.dtypes
# Out:
# controln     object
# state        object
# gender       object
# hv1         float64
# ic1           int64
# ic4         float64
# hvp1         object
# ic5         float64
# pobc1        object
# pobc2        object
# ic2         float64
# ic3           int64
# avggift     float64
# tcode        object
# dob          object
# domain       object
# target_d    float64
# dtype: object

# %%
data['hvp1'].unique() #shows unique values of the array or data set for this column
# Out:
# array([7, 0, 3, 1, 5, 61, 22, 97, 31, 4, 44, 2, 11, 6, 67, 30, 21, 74, 77,
#        56, 8, 25, 57, 63, 17, 24, 13, 94, 10, 85, 51, 19, 47, 99, 54, 81,
#        83, 49, 98, 91, 33, 18, 76, 16, 52, 15, 35, 96, 95, 58, 80, 93, 27,
#        84, 78, 66, 26, 34, 23, 87, 14, 73, 12, 71, 9, 75, 20, 48, 28, 37,
#        86, 59, 32, 60, 50, 68, 62, 89, 46, 72, 69, 88, 65, 45, 38, 92, 36,
#        82, 90, 39, 29, 70, 40, 55, 79, 53, 43, 64, 41, 42], dtype=object)

# %%
data['hvp1'].value_counts() #shows how many values of the array or data set for this column
# Out:
# 0     1593
# 1      526
# 2      220
# 3      163
# 4       94
#       ...
# 40       4
# 41       4
# 62       3
# 37       3
# 42       3
# Name: hvp1, Length: 100, dtype: int64

# %%
data=data.drop_duplicates() #deletes duplicate rows or data from the data frame

# %%
data.shape
# Out:
# (4001, 17)

# %% [markdown]
# ## extract resulting data frame as csv

# %%
#data.to_csv('day1.csv', index=False) #creates a new notebook with data from day1

# %% [markdown]
# ### Remove nulls

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4001 entries, 0 to 1000
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   controln  4001 non-null   object
#  1   state     4001 non-null   object
#  2   gender    3868 non-null   object
#  3   hv1       3991 non-null   float64
#  4   ic1       4001 non-null   int64
#  5   ic4       4000 non-null   float64
#  6   hvp1      4001 non-null   object
#  7   ic5       3995 non-null   float64
#  8   pobc1     4001 non-null   object
#  9   pobc2     4001 non-null   object
#  10  ic2       4000 non-null   float64
#  11  ic3       4001 non-null   int64
#  12  avggift   4001 non-null   float64
#  13  tcode     4001 non-null   object
#  14  dob       4001 non-null   object
#  15  domain    4001 non-null   object
#  16  target_d  4001 non-null   float64
# dtypes: float64(6), int64(2), object(9)
# memory usage: 562.6+ KB

# %%
#use this if we think we have any complete row nulls 
data.isna().all(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Length: 4001, dtype: bool

# %%
#nulls snapshot table as baseline
nullsdf=pd.DataFrame(round(data.isna().sum()/len(data),4)*100)

# %%
nullsdf
# Out:
#              0
# controln  0.00
# state     0.00
# gender    0.00
# hv1       0.00
# ic1       0.00
# ic4       0.02
# hvp1      0.00
# ic5       0.15
# pobc1     0.00
# pobc2     0.00
# ic2       0.02
# ic3       0.00
# avggift   0.00
# tcode     0.00
# dob       0.00
# domain    0.00
# target_d  0.00

# %%
nullsdf=nullsdf.rename(columns={'index':'header',0:'proportionnulls'})

# %%
nullsdf
# Out:
#           proportionnulls
# controln             0.00
# state                0.00
# gender               3.32
# hv1                  0.25
# ic1                  0.00
# ic4                  0.02
# hvp1                 0.00
# ic5                  0.15
# pobc1                0.00
# pobc2                0.00
# ic2                  0.02
# ic3                  0.00
# avggift              0.00
# tcode                0.00
# dob                  0.00
# domain               0.00
# target_d             0.00

# %%
data[data['gender'].isna()==True]
# Out:
#     controln state gender     hv1  ic1    ic4 hvp1      ic5 pobc1 pobc2  \
# 15     73699    MI    NaN   890.0  463  523.0    1   9493.0     5    53
# 21    114721    OK    NaN  1040.0  472  656.0    0  26962.0     2    56
# 22    111795    AR    NaN   603.0  208  341.0    2  12038.0     1    70
# 54    190671    CA    NaN  2143.0  280  373.0   63  12935.0    29    36
# 77    156324  Cali    NaN  2016.0  431  497.0   51  17882.0    11    53
# ..       ...   ...    ...     ...  ...    ...  ...      ...   ...   ...
# 790   187604    TN    NaN  1349.0  481  628.0   21  22094.0     4    45
# 860   187628    KY    NaN   896.0  455  507.0    1  18693.0     1    79
# 894    52588    TN    NaN   585.0  212  326.0    4  13218.0     1    71
# 946    65656    MI    NaN   928.0  334  527.0    1  23732.0    15    57
# 966    44800    FL    NaN   599.0  200  288.0    2  11547.0     3    34
#
#        ic2  ic3    avggift tcode   dob domain  target_d
# ...

# %%
data['gender']=data['gender'].fillna('Unknown')
# Out:
# /var/folders/gd/t7jqq6zs1zl6b6b62cxdkccw0000gn/T/ipykernel_1983/1906382416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender']=data['gender'].fillna('Unknown')

# %%
data[data['gender']=='Unknown']
# Out:
#     controln state   gender     hv1  ic1    ic4 hvp1      ic5 pobc1 pobc2  \
# 15     73699    MI  Unknown   890.0  463  523.0    1   9493.0     5    53
# 21    114721    OK  Unknown  1040.0  472  656.0    0  26962.0     2    56
# 22    111795    AR  Unknown   603.0  208  341.0    2  12038.0     1    70
# 54    190671    CA  Unknown  2143.0  280  373.0   63  12935.0    29    36
# 77    156324  Cali  Unknown  2016.0  431  497.0   51  17882.0    11    53
# ..       ...   ...      ...     ...  ...    ...  ...      ...   ...   ...
# 790   187604    TN  Unknown  1349.0  481  628.0   21  22094.0     4    45
# 860   187628    KY  Unknown   896.0  455  507.0    1  18693.0     1    79
# 894    52588    TN  Unknown   585.0  212  326.0    4  13218.0     1    71
# 946    65656    MI  Unknown   928.0  334  527.0    1  23732.0    15    57
# 966    44800    FL  Unknown   599.0  200  288.0    2  11547.0     3    34
#
#        ic2  ic3    avggift tcode   dob domain  target_d
# ...

# %% [markdown]
# ## numeric columns - fill in - fill with mean

# %%
hv1_mean=data["hv1"].mean()

# %%
# Replace nulls in hv1 with mean !

# %%
data['hv1']=data['hv1'].fillna(hv1_mean)
# Out:
# /var/folders/gd/t7jqq6zs1zl6b6b62cxdkccw0000gn/T/ipykernel_1983/3200100063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['hv1']=data['hv1'].fillna(hv1_mean)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4001 entries, 0 to 1000
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   controln  4001 non-null   object
#  1   state     4001 non-null   object
#  2   gender    4001 non-null   object
#  3   hv1       4001 non-null   float64
#  4   ic1       4001 non-null   int64
#  5   ic4       4000 non-null   float64
#  6   hvp1      4001 non-null   object
#  7   ic5       3995 non-null   float64
#  8   pobc1     4001 non-null   object
#  9   pobc2     4001 non-null   object
#  10  ic2       4000 non-null   float64
#  11  ic3       4001 non-null   int64
#  12  avggift   4001 non-null   float64
#  13  tcode     4001 non-null   object
#  14  dob       4001 non-null   object
#  15  domain    4001 non-null   object
#  16  target_d  4001 non-null   float64
# dtypes: float64(6), int64(2), object(9)
# memory usage: 562.6+ KB

# %%
#lambda

def functionname:
    return something ...

# %%
data['gender'].unique()
# Out:
# array(['M', 'F', 'female', 'Male', 'Unknown', 'U', 'J', 'male', 'Female',
#        'feamale', 'A'], dtype=object)

# %%
y= lambda x: x+2

# %%
y(200)
# Out:
# 202

# %%
multiplication= lambda x,y: x*y

# %%
multiplication(20,30)
# Out:
# 600

# %%
data['gender']=list(map(lambda x: x.upper(),data['gender']))
# Out:
# /var/folders/gd/t7jqq6zs1zl6b6b62cxdkccw0000gn/T/ipykernel_1983/3578288280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender']=list(map(lambda x: x.upper(),data['gender']))

# %% [markdown]
# ### list=[1,2,3,4,5,6,7,8]
#
#  - square just the even numbers in the list
#
#  - using lambda
#
#  - into a new_list

# %%
numbers=[1,2,3,4,5,6,7,8]
new_list=[]

for i in numbers:
    if i%2==0:
        lambda i: i**2

# %%
numbers=

# %%
def clean_gender(x):
    if x in ['M','MALE']:
        return 'M'
    elif x.startswith('F'):
        return 'F'
    else:
        return "UNKNOWN"

# %%
data['gender']=list(map(clean_gender,data['gender']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/gd/t7jqq6zs1zl6b6b62cxdkccw0000gn/T/ipykernel_1983/1399973028.py in <module>
# ----> 1 data['gender']=list(map(clean_gender,data['gender']))
#
# TypeError: 'list' object is not callable
